# %% [markdown]
# # PySCF graphene example
#
# Based on: https://github.com/pyscf/pyscf/tree/master/examples

# %%
from ase import Atoms
from ase.build import  bulk, graphene
from ase.io import read, write
from ase.visualize import view

graph=graphene(size=(15,15,1))

view(graph, viewer='x3d')
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="0.00 0.00 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="1.23 0.71 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.23 2.13 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="0.00 2.84 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.46 4.26 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-1.23 4.97 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-3.69 6.39 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-2.46 7.10 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-4.92 8.52 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-3.69 9.23 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-6.15 10.65 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-4.92 11.36 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-7.38 12.78 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-6.15 13.49 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-8.61 14.91 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-7.38 15.62 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-9.84 17.04 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-8.61 17.75 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-11.07 19.17 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-9.84 19.88 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-12.30 21.30 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-11.07 22.01 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-13.53 23.43 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-12.30 24.14 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-14.76 25.57 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-13.53 26.28 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-15.99 27.70 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="-14.76 28.41 0.00">

# %%
import time
from pyscf.pbc import df as pdf
from pyscf.pbc import gto as pbcgto
from pyscf.pbc import scf as pbchf

nk = 1
kpts = [nk,nk,1]
Lz = 25 # Smallest Lz value for ~1e-6 convergence in absolute energy
a = 1.42 # bond length in graphene
fft_ke_cut = 300
# Much smaller mesh needed for AFTDF with the setting cell.low_dim_ft_type='inf_vacuum'
aft_mesh = [30,30,40]
e = []
t = []
pseudo = 'gth-pade'

##################################################
#
# 2D PBC with FFT
#
##################################################
cell = pbcgto.Cell()
cell.build(unit = 'B',
           a = [[4.6298286730500005, 0.0, 0.0], [-2.3149143365249993, 4.009549246030899, 0.0], [0.0, 0.0, Lz]],
           atom = 'C 0 0 0; C 0 2.67303283 0',
           ke_cutoff = fft_ke_cut,
           dimension=2,
           pseudo = pseudo,
           verbose = 7,
           precision = 1e-6,
           basis='gth-szv')
t0 = time.time()
mf = pbchf.KRHF(cell, exxdiv='ewald')
mf.with_df = pdf.FFTDF(cell)
mf.kpts = cell.make_kpts(kpts)
mf.conv_tol = 1e-6
e.append(mf.kernel())
t.append(time.time() - t0)
# Out:
# System: uname_result(system='Linux', node='leaf', release='5.4.0-121-generic', version='#137-Ubuntu SMP Wed Jun 15 13:33:07 UTC 2022', machine='x86_64', processor='x86_64')  Threads 8
# Python 3.8.13 (default, Mar 28 2022, 11:38:47)
# [GCC 7.5.0]
# numpy 1.21.5  scipy 1.8.0
# Date: Fri Jun 24 15:42:29 2022
# PySCF version 2.0.1
# PySCF path  /home/nishida/software/anaconda3/lib/python3.8/site-packages/pyscf
#
# [CONFIG] DEBUG = False
# [CONFIG] MAX_MEMORY = 4000
# [CONFIG] TMPDIR = .
# [CONFIG] UNIT = angstrom
# [CONFIG] VERBOSE = 3
# [CONFIG] conf_file = None
# [INPUT] verbose = 7
# [INPUT] max_memory = 4000
# [INPUT] num. atoms = 2
# [INPUT] num. electrons = 8
# [INPUT] charge = 0
# [INPUT] spin (= nelec alpha-beta = 2S) = 0
# [INPUT] symmetry False subgroup None
# [INPUT] Mole.unit = B
# [INPUT]  1 C      0.000000000000   0.000000000000   0.000000000000 AA    0.000000000000   0.000000000000   0.000000000000 Bohr
# [INPUT]  2 C      0.000000000000   1.414508057677   0.000000000000 AA    0.000000000000   2.673032830000   0.000000000000 Bohr
# [INPUT] ---------------- BASIS SET ----------------
# [INPUT] l, kappa, [nprim/nctr], expnt,             c_1 c_2 ...
# [INPUT] C
# [INPUT] 0    0    [4    /1   ]  4.3362376436      0.1490797872
#                                 1.2881838513      -0.0292640031
#                                 0.4037767149      -0.688204051
#                                 0.1187877657      -0.3964426906
# [INPUT] 1    0    [4    /1   ]  4.3362376436      -0.0878123619
#                                 1.2881838513      -0.27755603
#                                 0.4037767149      -0.4712295093
#                                 0.1187877657      -0.4058039291
#
# Ewald components = 0.000596491497920777, -19.8209958545232, -0.0702454596540994
# nuclear repulsion = -19.8906448226794
# number of shells = 4
# number of NR pGTOs = 32
# number of NR cGTOs = 8
# basis = gth-szv
# ecp = {}
# bas 0, expnt(s) = [4.33623764 1.28818385 0.40377671 0.11878777]
# bas 1, expnt(s) = [4.33623764 1.28818385 0.40377671 0.11878777]
# bas 2, expnt(s) = [4.33623764 1.28818385 0.40377671 0.11878777]
# bas 3, expnt(s) = [4.33623764 1.28818385 0.40377671 0.11878777]
# CPU time:         1.27
# lattice vectors  a1 [4.629828673, 0.000000000, 0.000000000]
#                  a2 [-2.314914337, 4.009549246, 0.000000000]
#                  a3 [0.000000000, 0.000000000, 25.000000000]
# dimension = 2
# low_dim_ft_type = None
# Cell volume = 464.088
# rcut = 19.71356560618931 (nimgs = [5 5 1])
# lattice sum = 101 cells
# precision = 1e-06
# pseudo = gth-pade
# ke_cutoff = 300
#     = [ 32  32 195] mesh (199680 PWs)
#
#
# ******** <class 'pyscf.pbc.scf.khf.KRHF'> ********
# method = KRHF-KSCF-RHF-SCF-RHF
# initial guess = minao
# damping factor = 0
# level_shift factor = 0
# DIIS = <class 'pyscf.scf.diis.CDIIS'>
# diis_start_cycle = 1
# diis_space = 8
# SCF conv_tol = 1e-06
# SCF conv_tol_grad = None
# SCF max_cycles = 50
# direct_scf = True
# direct_scf_tol = 1e-13
# chkfile to save SCF result = /home/nishida/git/openfermion_samples/tmps0bsckvi
# max_memory 4000 MB (current use 148 MB)
#
#
# ******** PBC SCF flags ********
# N kpts = 1
# kpts = [[0. 0. 0.]]
# Exchange divergence treatment (exxdiv) = ewald
# Monkhorst pack size [1 1 1] ew_eta 1.0978687634728737 ew_cut 5.748598281516584
# Ewald components = 4.24875213041003e-13, -0.619406120453851, 0.164376039031296
#     madelung (= occupied orbital energy shift) = 0.9100601628442602
#     Total energy shift due to Ewald probe charge = -1/2 * Nelec*madelung = -3.64024065138
# DF object = <pyscf.pbc.df.fft.FFTDF object at 0x7f1b0d9b7af0>
#
#
# ******** <class 'pyscf.pbc.df.fft.FFTDF'> ********
# mesh = [ 32  32 195] (199680 PWs)
# len(kpts) = 1
#     kpts = [[0. 0. 0.]]
# Set gradient conv threshold to 0.001
# Big error detected in the electron number of initial guess density matrix (Ne/cell = 10.1531)!
#   This can cause huge error in Fock matrix and lead to instability in SCF for low-dimensional systems.
#   DM is normalized wrt the number of electrons 8.0
# WARNING!
#   Size of vacuum may not be enough. The recommended vacuum size is 20.863939329543395 AA (39.42713121237862 Bohr)
# fft_jk: get_k_kpts max_memory 3700.824064  blksize 8
#     CPU time for get_k_kpts: make_kpt (0,*)      9.03 sec, wall time      1.24 sec
# Monkhorst pack size [1 1 1] ew_eta 1.0978687634728737 ew_cut 5.748598281516584
# Ewald components = 4.24875213041003e-13, -0.619406120453851, 0.164376039031296
#     CPU time for vj and vk     15.18 sec, wall time      2.09 sec
# Ewald components = 0.000596491497920777, -19.8209958545232, -0.0702454596540994
# E1 = 25.376981125374687  E_coul = -18.944155991431593
# init E= -13.4578196887363
# cond(S) = [21.59019379]
#     CPU time for initialize scf     19.35 sec, wall time      2.68 sec
# HOMO = -0.496991211075  LUMO = 0.106077317554
#      k-point                  mo_energy
#    0 ( 0.000  0.000  0.000)   [-2.15423138 -0.93354694 -0.49699121 -0.49699121] [0.10607732 0.10607732 0.20063351 0.2698312 ]
# fft_jk: get_k_kpts max_memory 3684.296704  blksize 8
#     CPU time for get_k_kpts: make_kpt (0,*)      4.01 sec, wall time      0.54 sec
# Monkhorst pack size [1 1 1] ew_eta 1.0978687634728737 ew_cut 5.748598281516584
# Ewald components = 4.24875213041003e-13, -0.619406120453851, 0.164376039031296
#     CPU time for vj and vk      9.77 sec, wall time      1.31 sec
# Ewald components = 0.000596491497920777, -19.8209958545232, -0.0702454596540994
# E1 = 25.564120909903906  E_coul = -16.369546468187444
# cycle= 1 E= -10.6960703809629  delta_E= 2.76  |g|= 5.6e-12  |ddm|= 3.97
#     CPU time for cycle= 1      9.88 sec, wall time      1.33 sec
# diis-norm(errvec)=5.47284e-12
# diis-c [-2.99520182e-23  1.00000000e+00]
# HOMO = -0.627392971205  LUMO = 0.34024311459
#      k-point                  mo_energy
#    0 ( 0.000  0.000  0.000)   [-1.42077849 -0.76965728 -0.76965728 -0.62739297] [0.34024311 0.34024312 0.44487391 0.56376136]
# fft_jk: get_k_kpts max_memory 3684.153344  blksize 8
#     CPU time for get_k_kpts: make_kpt (0,*)      3.82 sec, wall time      0.51 sec
# Monkhorst pack size [1 1 1] ew_eta 1.0978687634728737 ew_cut 5.748598281516584
# Ewald components = 4.24875213041003e-13, -0.619406120453851, 0.164376039031296
#     CPU time for vj and vk      9.57 sec, wall time      1.29 sec
# Ewald components = 0.000596491497920777, -19.8209958545232, -0.0702454596540994
# E1 = 25.56412090990389  E_coul = -16.369546468187437
# cycle= 2 E= -10.696070380963  delta_E= -7.11e-15  |g|= 1.19e-12  |ddm|= 6.18e-12
#     CPU time for cycle= 2      9.71 sec, wall time      1.31 sec
# HOMO = -0.627392971205  LUMO = 0.34024311459
#      k-point                  mo_energy
#    0 ( 0.000  0.000  0.000)   [-1.42077849 -0.76965728 -0.76965728 -0.62739297] [0.34024311 0.34024312 0.44487391 0.56376136]
# fft_jk: get_k_kpts max_memory 3684.460544  blksize 8
#     CPU time for get_k_kpts: make_kpt (0,*)      4.06 sec, wall time      0.55 sec
# Monkhorst pack size [1 1 1] ew_eta 1.0978687634728737 ew_cut 5.748598281516584
# Ewald components = 4.24875213041003e-13, -0.619406120453851, 0.164376039031296
#     CPU time for vj and vk      9.85 sec, wall time      1.32 sec
# Ewald components = 0.000596491497920777, -19.8209958545232, -0.0702454596540994
# E1 = 25.56412090990392  E_coul = -16.36954646818749
# Extra cycle  E= -10.696070380963  delta_E= -2.49e-14  |g|= 4.25e-13  |ddm|= 2.49e-12
#     CPU time for scf_cycle     48.93 sec, wall time      6.65 sec
#     CPU time for SCF     49.05 sec, wall time      6.68 sec
# converged SCF energy = -10.696070380963

# %%
from ase.lattice import bulk
from ase.dft.kpoints import sc_special_points as special_points, get_bandpath

# %%
points = special_points['hexagonal']
G = points['G']
M = points['M']
K = points['K']
band_kpts, kpath, sp_points = get_bandpath([G, M, K, G], cell.a, npoints=50)
band_kpts = cell.get_abs_kpts(band_kpts)
# Out:
# /home/nishida/software/anaconda3/lib/python3.8/site-packages/ase/dft/kpoints.py:357: UserWarning: Please do not use (kpts, x, X) = bandpath(...).  Use path = bandpath(...) and then kpts = path.kpts and (x, X, labels) = path.get_linear_kpoint_axis().
#   warnings.warn('Please do not use (kpts, x, X) = bandpath(...).  '

# %%
#band_kpts
#e_kn_2

# %%
e_kn_2 = mf.get_bands(band_kpts)[0]
vbmax = -99
for en in e_kn_2:
    vb_k = en[cell.nelectron//2-1]
    if vb_k > vbmax:
        vbmax = vb_k
e_kn_2 = [en - vbmax for en in e_kn_2]

au2ev = 27.21139

emin = -1*au2ev
emax = 1*au2ev
# Out:
# fft_jk: get_k_kpts max_memory 2276.01408  blksize 5
#     CPU time for get_k_kpts: make_kpt (0,*)    513.64 sec, wall time     70.97 sec
# Monkhorst pack size [1 1 1] ew_eta 1.0978687634728737 ew_cut 5.748598281516584
# Ewald components = 4.24875213041003e-13, -0.619406120453851, 0.164376039031296
#     CPU time for vj and vk    545.77 sec, wall time     75.56 sec

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(5, 6))
nbands = cell.nao_nr()
for n in range(nbands):
    plt.plot(kpath, [e[n]*au2ev for e in e_kn_2], color='#4169E1')
for p in sp_points:
    plt.plot([p, p], [emin, emax], 'k-')
plt.plot([0, sp_points[-1]], [0, 0], 'k-')
plt.xticks(sp_points, ['$%s$' % n for n in [r'\Gamma', 'M', 'K', r'\Gamma']])
plt.axis(xmin=0, xmax=sp_points[-1], ymin=emin, ymax=emax)
plt.xlabel('k-vector')

plt.show()
