# %% [markdown]
# ## PySCF with OpenFermion
#
# Graphene nanoribon calculated with PySCF with OpenFermion.
#
#
# Based on the example from [https://github.com/quantumlib/OpenFermion-PySCF](https://github.com/quantumlib/OpenFermion-PySCF)

# %%
from ase.visualize import view
from ase.build import graphene_nanoribbon
gnr1 = graphene_nanoribbon(2, 2, type='armchair', saturated=True, vacuum=3.5)
#gnr1 = graphene_nanoribbon(3, 4, type='zigzag', saturated=True, vacuum=3.5)
view(gnr1, viewer='x3d')
# Out:
# <html>
#
#  <head>
#
#   <title>ASE atomic visualization</title>
#
#   <link rel="stylesheet" type="text/css"
#
#    href="https://www.x3dom.org/x3dom/release/x3dom.css">
#
#   </link>
#
#   <script type="text/javascript"
#
#    src="https://www.x3dom.org/x3dom/release/x3dom.js">
#
#   </script>
#
#  </head>
#
#  <body>
#
#   <X3D>
#
#    <Scene>
#
#     <Transform translation="6.90 3.50 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="8.13 3.50 0.71">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="8.13 3.50 2.13">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="6.90 3.50 2.84">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="6.90 3.50 4.26">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="8.13 3.50 4.97">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="8.13 3.50 6.39">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="6.90 3.50 7.10">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.44 3.50 0.00">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.67 3.50 0.71">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.67 3.50 2.13">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.44 3.50 2.84">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.44 3.50 4.26">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.67 3.50 4.97">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="5.67 3.50 6.39">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="4.44 3.50 7.10">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="0.565 0.565 0.565" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.76">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.50 3.50 0.55">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.50 3.50 2.29">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.50 3.50 4.80">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="3.50 3.50 6.55">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="9.08 3.50 0.16">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="9.08 3.50 2.67">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="9.08 3.50 4.42">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#     <Transform translation="9.08 3.50 6.93">
#
#      <Shape>
#
#       <Appearance>
#
#        <Material diffuseColor="1.000 1.000 1.000" specularColor="0.5 0.5 0.5">
#
#        </Material>
#
#       </Appearance>
#
#       <Sphere radius="0.31">
#
#       </Sphere>
#
#      </Shape>
#
#     </Transform>
#
#    </Scene>
#
#   </X3D>
#
#  </body>
#
# </html>

# %%
from ase.io.xyz import write_xyz
import io

f = io.StringIO()
gnr1.write(f,format='xyz')
graphene_geometry=[(a.split()[0],(float(a.split()[1]),float(a.split()[2]),float(a.split()[3]))) for a in f.getvalue().split('\n')[2:-1]]

# %%
graphene_geometry
# Out:
# [('C', (6.903479836872844, 3.5, 0.0)),
#  ('C', (8.133235910246746, 3.5, 0.71)),
#  ('C', (8.133235910246746, 3.5, 2.13)),
#  ('C', (6.903479836872844, 3.5, 2.84)),
#  ('C', (6.903479836872844, 3.5, 4.26)),
#  ('C', (8.133235910246746, 3.5, 4.97)),
#  ('C', (8.133235910246746, 3.5, 6.39)),
#  ('C', (6.903479836872844, 3.5, 7.1)),
#  ('C', (4.443967690125039, 3.5, 0.0)),
#  ('C', (5.673723763498941, 3.5, 0.71)),
#  ('C', (5.673723763498941, 3.5, 2.13)),
#  ('C', (4.443967690125039, 3.5, 2.84)),
#  ('C', (4.443967690125039, 3.5, 4.26)),
#  ('C', (5.673723763498941, 3.5, 4.97)),
#  ('C', (5.673723763498941, 3.5, 6.39)),
#  ('C', (4.443967690125039, 3.5, 7.1)),
#  ('H', (3.5, 3.5, 0.545)),
#  ('H', (3.5, 3.5, 2.295)),
#  ('H', (3.5, 3.5, 4.805)),
#  ('H', (3.5, 3.5, 6.555)),
#  ('H', (9.077203600371785, 3.5, 0.165)),
#  ('H', (9.077203600371785, 3.5, 2.675)),
#  ('H', (9.077203600371785, 3.5, 4.425)),
#  ('H', (9.077203600371785, 3.5, 6.935))]

# %%
from openfermion.chem import MolecularData
from openfermionpyscf import run_pyscf

# Set molecule parameters.
basis = 'sto-3g'
multiplicity = 1

# Set calculation parameters.
run_scf = 1
run_mp2 = 0 
run_cisd = 0
run_ccsd = 0
run_fci = 0

molecule = MolecularData(
    graphene_geometry, basis, multiplicity,
    description="graphene nanoribbon")

# Run pyscf.
molecule = run_pyscf(molecule,
                     run_scf=run_scf,
                     run_mp2=run_mp2,
                     run_cisd=run_cisd,
                     run_ccsd=run_ccsd,
                     run_fci=run_fci)


print(f'Hartree-Fock energy of {molecule.hf_energy} Hartree.')
print(f'Nuclear repulsion energy between protons is {molecule.nuclear_repulsion} Hartree.')
for orbital in range(molecule.n_orbitals):
    print(f'Spatial orbital {orbital} has energy of {molecule.orbital_energies[orbital]} Hartree.')
# Out:
# Hartree-Fock energy of -602.3486206423885 Hartree.
# Nuclear repulsion energy between protons is 904.5048088363402 Hartree.
# Spatial orbital 0 has energy of -11.082713237911422 Hartree.
# Spatial orbital 1 has energy of -11.082644232762357 Hartree.
# Spatial orbital 2 has energy of -11.079132593319303 Hartree.
# Spatial orbital 3 has energy of -11.07907597223062 Hartree.
# Spatial orbital 4 has energy of -11.065437971883311 Hartree.
# Spatial orbital 5 has energy of -11.06537625906105 Hartree.
# Spatial orbital 6 has energy of -11.056632556490058 Hartree.
# Spatial orbital 7 has energy of -11.056403869475128 Hartree.
# Spatial orbital 8 has energy of -11.051403382925034 Hartree.
# Spatial orbital 9 has energy of -11.051403071763023 Hartree.
# Spatial orbital 10 has energy of -11.044772962906448 Hartree.
# Spatial orbital 11 has energy of -11.044769052368473 Hartree.
# Spatial orbital 12 has energy of -11.028332876343844 Hartree.
# Spatial orbital 13 has energy of -11.028332653497234 Hartree.
# Spatial orbital 14 has energy of -10.954726223372274 Hartree.
# Spatial orbital 15 has energy of -10.954725977255478 Hartree.
# Spatial orbital 16 has energy of -1.1549264041769272 Hartree.
# Spatial orbital 17 has energy of -1.1035968789625739 Hartree.
# Spatial orbital 18 has energy of -1.0520703860989915 Hartree.
# Spatial orbital 19 has energy of -1.020524163139122 Hartree.
# Spatial orbital 20 has energy of -1.003644776987883 Hartree.
# Spatial orbital 21 has energy of -0.942223743579818 Hartree.
# Spatial orbital 22 has energy of -0.9346470254508837 Hartree.
# Spatial orbital 23 has energy of -0.8594436967945628 Hartree.
# Spatial orbital 24 has energy of -0.8322238980762288 Hartree.
# Spatial orbital 25 has energy of -0.8181927361114201 Hartree.
# Spatial orbital 26 has energy of -0.7775713670422841 Hartree.
# Spatial orbital 27 has energy of -0.7493665462520991 Hartree.
# Spatial orbital 28 has energy of -0.6879879061518487 Hartree.
# Spatial orbital 29 has energy of -0.6697676329571238 Hartree.
# Spatial orbital 30 has energy of -0.6692545229491376 Hartree.
# Spatial orbital 31 has energy of -0.633103906549289 Hartree.
# Spatial orbital 32 has energy of -0.5934645082078202 Hartree.
# Spatial orbital 33 has energy of -0.5797555845891569 Hartree.
# Spatial orbital 34 has energy of -0.5646461245663931 Hartree.
# Spatial orbital 35 has energy of -0.5439966951197739 Hartree.
# Spatial orbital 36 has energy of -0.5353498029377246 Hartree.
# Spatial orbital 37 has energy of -0.5274757185664861 Hartree.
# Spatial orbital 38 has energy of -0.5262839708355601 Hartree.
# Spatial orbital 39 has energy of -0.5177789564331441 Hartree.
# Spatial orbital 40 has energy of -0.466955554288899 Hartree.
# Spatial orbital 41 has energy of -0.4600148226861899 Hartree.
# Spatial orbital 42 has energy of -0.45573961757813675 Hartree.
# Spatial orbital 43 has energy of -0.41848344203917665 Hartree.
# Spatial orbital 44 has energy of -0.3901951008865333 Hartree.
# Spatial orbital 45 has energy of -0.3502902702107769 Hartree.
# Spatial orbital 46 has energy of -0.3275293220852486 Hartree.
# Spatial orbital 47 has energy of -0.24872949551829845 Hartree.
# Spatial orbital 48 has energy of -0.24634541912506405 Hartree.
# Spatial orbital 49 has energy of -0.24103389371080094 Hartree.
# Spatial orbital 50 has energy of -0.24017107181372394 Hartree.
# Spatial orbital 51 has energy of -0.12523713405496797 Hartree.
# Spatial orbital 52 has energy of -0.04801504462084731 Hartree.
# Spatial orbital 53 has energy of 0.11417259431087852 Hartree.
# Spatial orbital 54 has energy of 0.1555321126614118 Hartree.
# Spatial orbital 55 has energy of 0.2263693395481131 Hartree.
# Spatial orbital 56 has energy of 0.24010147213724983 Hartree.
# Spatial orbital 57 has energy of 0.3198394265915443 Hartree.
# Spatial orbital 58 has energy of 0.3525726964719407 Hartree.
# Spatial orbital 59 has energy of 0.37791555718093445 Hartree.
# Spatial orbital 60 has energy of 0.48896846549359707 Hartree.
# Spatial orbital 61 has energy of 0.538458731826869 Hartree.
# Spatial orbital 62 has energy of 0.5589792160100785 Hartree.
# Spatial orbital 63 has energy of 0.5877996593016382 Hartree.
# Spatial orbital 64 has energy of 0.5975348291372367 Hartree.
# Spatial orbital 65 has energy of 0.6210984335545152 Hartree.
# Spatial orbital 66 has energy of 0.6279906225271814 Hartree.
# Spatial orbital 67 has energy of 0.6616647839490816 Hartree.
# Spatial orbital 68 has energy of 0.6631553729757274 Hartree.
# Spatial orbital 69 has energy of 0.6693050742992158 Hartree.
# Spatial orbital 70 has energy of 0.6793240151519144 Hartree.
# Spatial orbital 71 has energy of 0.7411083702927896 Hartree.
# Spatial orbital 72 has energy of 0.7461431164289617 Hartree.
# Spatial orbital 73 has energy of 0.756380649833282 Hartree.
# Spatial orbital 74 has energy of 0.7869492040854676 Hartree.
# Spatial orbital 75 has energy of 0.797228311886977 Hartree.
# Spatial orbital 76 has energy of 0.821024451877775 Hartree.
# Spatial orbital 77 has energy of 0.8334411477033222 Hartree.
# Spatial orbital 78 has energy of 0.8701318434308469 Hartree.
# Spatial orbital 79 has energy of 0.8952446775573033 Hartree.
# Spatial orbital 80 has energy of 0.9078970145461016 Hartree.
# Spatial orbital 81 has energy of 0.9461220386192271 Hartree.
# Spatial orbital 82 has energy of 0.9668394716909264 Hartree.
# Spatial orbital 83 has energy of 0.9842899798727871 Hartree.
# Spatial orbital 84 has energy of 1.0510754062380803 Hartree.
# Spatial orbital 85 has energy of 1.0554651316891435 Hartree.
# Spatial orbital 86 has energy of 1.128228813372084 Hartree.
# Spatial orbital 87 has energy of 1.1517991482034398 Hartree.

# %%
from openfermionpyscf import run_pyscf, generate_molecular_hamiltonian 
from openfermion.transforms import get_fermion_operator, jordan_wigner

# %%
#CAS(2,2)

n_active_electrons = 2
n_active_orbitals = 2

molecule = generate_molecular_hamiltonian(                                                                  
    geometry=graphene_geometry,                                                                                               
    basis=basis,                                                                                            
    multiplicity=multiplicity,                                                                              
    charge=0,                                                                                         
    n_active_electrons=n_active_electrons,                                                            
    n_active_orbitals=n_active_orbitals)                                                               
    
molecule_qubit_hamiltonian_cas22 = jordan_wigner(get_fermion_operator(molecule)) 
molecule_qubit_hamiltonian_cas22
# Out:
# (-602.3093339159215+0j) [] +
# (-0.05742396824508688+0j) [X0 X1 Y2 Y3] +
# (0.05742396824508688+0j) [X0 Y1 Y2 X3] +
# (1.8908335976676234e-08+0j) [X0 Z1 X2] +
# (4.399578077015926e-08+0j) [X0 Z1 X2 Z3] +
# 1.0998945194971647e-08j [X0 Z1 Y2] +
# (0.05742396824508688+0j) [Y0 X1 X2 Y3] +
# (-0.05742396824508688+0j) [Y0 Y1 X2 X3] +
# -1.0998945194971647e-08j [Y0 Z1 X2] +
# (1.8908335976676234e-08+0j) [Y0 Z1 Y2] +
# (4.399578077015926e-08+0j) [Y0 Z1 Y2 Z3] +
# (0.04343904832500831+0j) [Z0] +
# (0.07619633443039164+0j) [Z0 Z1] +
# (0.018975948074565256+0j) [Z0 Z2] +
# (0.07639991631965212+0j) [Z0 Z3] +
# (1.8908335976676237e-08+0j) [X1 Z2 X3] +
# (4.3995780770159256e-08+0j) [X1 X3] +
# (1.8908335976676237e-08+0j) [Y1 Z2 Y3] +
# (4.3995780770159256e-08+0j) [Y1 Y3] +
# (0.04343904832500831+0j) [Z1] +
# (0.07639991631965212+0j) [Z1 Z2] +
# (0.018975948074565256+0j) [Z1 Z3] +
# (0.042763359092230176+0j) [Z2] +
# (0.076620046352663+0j) [Z2 Z3] +
# (0.04276335909223016+0j) [Z3]
